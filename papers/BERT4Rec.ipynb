# %% [markdown]
# ## 參考
# - [BST - keras.io](https://keras.io/examples/structured_data/movielens_recommendations_transformers/)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow import keras 
from tensorflow.keras import layers

# %%
# 讀取資料 from .dat

data_dir = 'ml-1m/ml-1m'

users = pd.read_csv(data_dir+'/users.dat', delimiter='::', names=['user_id', 'gender', 'age', 'occupation', 'zip_code'])
movies = pd.read_csv(data_dir+'/movies.dat', delimiter='::', names=['movie_id', 'title', 'genres'])
ratings = pd.read_csv(data_dir+'/ratings.dat', delimiter='::', names=['user_id', 'movie_id', 'rating', 'timestamp'])
# Out:
# C:\Users\aband\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# C:\Users\aband\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# C:\Users\aband\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   import sys

# %%
users.head()
# Out:
#    user_id gender  age  occupation zip_code
# 0        1      F    1          10    48067
# 1        2      M   56          16    70072
# 2        3      M   25          15    55117
# 3        4      M   45           7    02460
# 4        5      M   25          20    55455

# %%
movies.head()
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000209 entries, 0 to 1000208
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   user_id    1000209 non-null  int64
#  1   movie_id   1000209 non-null  int64
#  2   rating     1000209 non-null  int64
#  3   timestamp  1000209 non-null  int64
# dtypes: int64(4)
# memory usage: 30.5 MB

# %%
# 先透過df frame 排序, 之後用group by就可以得到正確順序(會保持原順序)

ratings.sort_values(by=['user_id', 'timestamp'], inplace=True, ascending=True)

# %%
ratings
# Out:
#          user_id  movie_id  rating  timestamp
# 31             1      3186       4  978300019
# 22             1      1270       5  978300055
# 27             1      1721       4  978300055
# 37             1      1022       5  978300055
# 24             1      2340       3  978300103
# ...          ...       ...     ...        ...
# 1000019     6040      2917       4  997454429
# 999988      6040      1921       4  997454464
# 1000172     6040      1784       3  997454464
# 1000167     6040       161       3  997454486
# 1000042     6040      1221       4  998315055
#
# [1000209 rows x 4 columns]

# %%
# 取得重要參數, 就是總movie 數目, +1即可用於[mask]

num_movies = len(movies['movie_id'].unique())
num_users = len(users['user_id'].unique())

print(f'電影數量: {num_movies}\n使用者數量: {num_users}')
# Out:
# 電影數量: 3883
# 使用者數量: 6040

# %%
# 中間有斷, 有點麻煩, 需要重新排序, 或者將數量提升, 沒有的就沒用到而已, okay這樣比較方便。

num_movies = movies['movie_id'].max() + 1
mask_token_id = movies['movie_id'].max() + 1
movies['movie_id'].max()
# Out:
# 3952

# %%
# 整理成論文需要的資料
# [movie1, movie2, movie3, movie4, movie5...100]
# N = 100
from pprint import pprint

# 透過ratings, 利用groupby user_id, timestamp


groups = ratings.groupby(by=['user_id']).groups

# %%
lengths = 0

for key in groups:
    print(f'user_id(${key}): 長度(${len(groups[key])})')
    lengths += len(groups[key])
    print('-'*15)
    pprint(groups[key])
# Out:
# user_id($1): 長度($53)
# ---------------
# Int64Index([31, 22, 27, 37, 24, 36,  3,  7, 47,  0, 21, 44,  9, 51, 43, 41, 48,
#             18, 11, 14, 42, 17, 39, 45, 26,  2,  6, 19, 38, 52,  1, 13, 49, 50,
#             15, 20, 46,  5,  8, 12, 28, 23, 10, 16, 29, 33, 40,  4, 30, 35, 32,
#             34, 25],
#            dtype='int64')
# user_id($2): 長度($129)
# ---------------
# Int64Index([130,  64,  71, 134,  88, 170, 106, 120, 172,  70,
#             ...
#              92, 129, 167,  74,  80, 133,  66,  73,  87, 136],
#            dtype='int64', length=129)
# user_id($3): 長度($51)
# ---------------
# Int64Index([217, 202, 186, 230, 190, 225, 209, 216, 218, 226, 212, 201, 211,
#             228, 214, 215, 223, 189, 195, 198, 199, 205, 207, 194, 197, 210,
#             227, 222, 229, 204, 206, 224, 184, 188, 231, 203, 182, 185, 193,
#             220, 200, 221, 192, 196, 208, 183, 213, 219, 187, 191, 232],
#            dtype='int64')
# user_id($4): 長度($21)
# ---------------
# Int64Index([234, 244, 233, 240, 249, 238, 241, 242, 248, 239, 247, 250, 251,
#             252, 236, 245, 246, 253, 235, 237, 243],
#            dtype='int64')
# user_id($5): 長度($198)
# ---------------
# Int64Index([325, 378, 410, 275, 448, 299, 329, 432, 414, 422,
#             ...
#             304, 429, 391, 441, 296, 389, 324, 372, 418, 258],
#            dtype='int64', length=198)
# user_id($6): 長度($71)
# ---------------
# Int64Index([461, 481, 505, 470, 487, 489, 472, 501, 503, 493, 495, 482, 502,
#             513, 519, 486, 514, 452, 453, 460, 504, 511, 478, 466, 471, 512,
#             509, 518, 477, 483, 469, 515, 473, 499, 463, 496, 522, 468, 474,
#             456, 459, 464, 479, 506, 455, 516, 457, 485, 498, 507, 521, 484,
#             492, 494, 462, 476, 500, 465, 467, 491, 497, 458, 490, 488, 508,
#             510, 520, 454, 517, 480, 475],
#            dtype='int64')
# user_id($7): 長度($31)
# ---------------
# Int64Index([539, 551, 531, 535, 549, 523, 526, 527, 538, 542, 528, 529, 536,
#             540, 548, 550, 533, 553, 525, 530, 532, 544, 547, 524, 534, 537,
#             541, 545, 546, 552, 543],
#            dtype='int64')
# user_id($8): 長度($139)
# ---------------
# Int64Index([631, 646, 641, 670, 629, 660, 576, 623, 652, 667,
#             ...
#             583, 689, 590, 566, 568, 565, 609, 581, 610, 642],
#            dtype='int64', length=139)
# user_id($9): 長度($106)
# ---------------
# Int64Index([752, 795, 777, 753, 751, 769, 785, 714, 734, 787,
#             ...
#             791, 798, 731, 774, 766, 749, 696, 707, 702, 741],
#            dtype='int64', length=106)
# user_id($10): 長度($401)
# ---------------
# Int64Index([ 869,  880,  998,  943, 1116,  900,  947, 1115, 1154, 1040,
#             ...
#              981,  919,  868,  864,  987, 1069,  902, 1004, 1148,  983],
#            dtype='int64', length=401)
# user_id($11): 長度($137)
# ---------------
# Int64Index([1217, 1208, 1309, 1229, 1218, 1283, 1279, 1301, 1295, 1241,
#             ...
#             1317, 1270, 1273, 1296, 1269, 1243, 1261, 1275, 1224, 1314],
#            dtype='int64', length=137)
# user_id($12): 長度($23)
# ---------------
# Int64Index([1348, 1350, 1356, 1357, 1358, 1353, 1354, 1340, 1342, 1343, 1347,
#             1352, 1345, 1355, 1339, 1351, 1341, 1349, 1359, 1337, 1344, 1346,
#             1338],
#            dtype='int64')
# user_id($13): 長度($108)
# ---------------
# Int64Index([1374, 1391, 1369, 1372, 1421, 1437, 1460, 1384, 1431, 1380,
#             ...
#             1464, 1370, 1451, 1455, 1363, 1367, 1379, 1393, 1401, 1405],
#            dtype='int64', length=108)
# user_id($14): 長度($25)
# ---------------
# Int64Index([1474, 1481, 1492, 1473, 1485, 1484, 1471, 1476, 1486, 1469, 1480,
#             1489, 1482, 1468, 1475, 1477, 1479, 1478, 1487, 1491, 1483, 1488,
#             1470, 1472, 1490],
#            dtype='int64')
# user_id($15): 長度($201)
# ---------------
# Int64Index([1537, 1523, 1493, 1586, 1654, 1504, 1546, 1566, 1575, 1619,
#             ...
#             1556, 1560, 1656, 1519, 1547, 1555, 1524, 1693, 1659, 1520],
#            dtype='int64', length=201)
# user_id($16): 長度($35)
# ---------------
# Int64Index([1706, 1715, 1702, 1695, 1697, 1701, 1705, 1707, 1717, 1719, 1720,
#             1722, 1728, 1708, 1710, 1704, 1716, 1723, 1725, 1724, 1709, 1721,
#             1696, 1703, 1718, 1726, 1700, 1711, 1714, 1713, 1727, 1698, 1712,
#             1694, 1699],
#            dtype='int64')
# user_id($17): 長度($211)
# ---------------
# Int64Index([1738, 1747, 1805, 1843, 1759, 1763, 1764, 1889, 1932, 1748,
#             ...
#             1790, 1796, 1799, 1898, 1912, 1918, 1761, 1826, 1848, 1925],
#            dtype='int64', length=211)
# user_id($18): 長度($305)
# ---------------
# Int64Index([2039, 2044, 2118, 2176, 2233, 2224, 1994, 2053, 2143, 2186,
#             ...
#             1987, 2000, 2132, 2054, 1988, 2045, 2073, 2056, 2146, 1946],
#            dtype='int64', length=305)
# user_id($19): 長度($255)
# ---------------
# Int64Index([2469, 2298, 2432, 2457, 2497, 2291, 2293, 2351, 2292, 2386,
#             ...
#             2287, 2277, 2247, 2275, 2319, 2320, 2349, 2342, 2327, 2492],
#            dtype='int64', length=255)
# user_id($20): 長度($24)
# ---------------
# Int64Index([2522, 2516, 2515, 2514, 2501, 2500, 2519, 2502, 2505, 2506, 2518,
#             2521, 2508, 2503, 2512, 2513, 2517, 2504, 2510, 2520, 2507, 2511,
#             2523, 2509],
#            dtype='int64')
# user_id($21): 長度($22)
# ---------------
# Int64Index([2526, 2527, 2534, 2535, 2540, 2541, 2543, 2545, 2530, 2532, 2542,
#             2524, 2525, 2529, 2536, 2537, 2528, 2539, 2531, 2538, 2544, 2533],
#            dtype='int64')
# user_id($22): 長度($297)
# ---------------
# Int64Index([2582, 2695, 2780, 2840, 2783, 2802, 2713, 2748, 2782, 2664,
#             ...
#             2776, 2827, 2839, 2610, 2778, 2809, 2709, 2623, 2646, 2657],
#            dtype='int64', length=297)
# user_id($23): 長度($304)
# ---------------
# Int64Index([2935, 2948, 3021, 2889, 2983, 3010, 2844, 2869, 2960, 3025,
#             ...
#             2974, 2998, 3011, 2924, 2981, 3012, 2890, 2902, 3143, 2891],
#            dtype='int64', length=304)
# user_id($24): 長度($136)
# ---------------
# Int64Index([3180, 3216, 3222, 3232, 3262, 3227, 3176, 3152, 3186, 3242,
#             ...
#             3167, 3191, 3151, 3217, 3162, 3251, 3223, 3211, 3213, 3179],
#            dtype='int64', length=136)
# user_id($25): 長度($85)
# ---------------
# Int64Index([3328, 3298, 3284, 3363, 3325, 3341, 3293, 3297, 3300, 3335, 3336,
#             3313, 3289, 3324, 3290, 3303, 3344, 3357, 3332, 3287, 3316, 3333,
#             3283, 3285, 3315, 3296, 3304, 3356, 3301, 3306, 3321, 3360, 3364,
#             3319, 3307, 3329, 3330, 3323, 3342, 3322, 3349, 3355, 3361, 3314,
#             3318, 3340, 3352, 3353, 3365, 3311, 3292, 3348, 3310, 3331, 3312,
#             3367, 3302, 3334, 3288, 3317, 3337, 3343, 3339, 3294, 3338, 3320,
#             3299, 3326, 3345, 3358, 3362, 3295, 3305, 3309, 3359, 3327, 3291,
#             3308, 3346, 3354, 3366, 3351, 3350, 3347, 3286],
#            dtype='int64')
# user_id($26): 長度($400)
# ---------------
# Int64Index([3421, 3581, 3603, 3717, 3673, 3405, 3454, 3604, 3646, 3491,
#             ...
#             3373, 3659, 3589, 3703, 3534, 3469, 3670, 3566, 3451, 3514],
#            dtype='int64', length=400)
# user_id($27): 長度($70)
# ---------------
# Int64Index([3805, 3785, 3819, 3816, 3832, 3769, 3770, 3811, 3813, 3817, 3812,
#             3825, 3788, 3771, 3776, 3799, 3801, 3809, 3831, 3781, 3783, 3806,
#             3768, 3777, 3803, 3828, 3790, 3796, 3810, 3835, 3775, 3786, 3800,
#             3814, 3772, 3815, 3826, 3774, 3792, 3807, 3824, 3793, 3791, 3808,
#             3782, 3780, 3795, 3797, 3822, 3837, 3830, 3834, 3778, 3820, 3802,
#             3818, 3836, 3798, 3829, 3789, 3794, 3823, 3833, 3787, 3827, 3804,
#             3773, 3779, 3784, 3821],
#            dtype='int64')
# user_id($28): 長度($107)
# ---------------
# Int64Index([3851, 3870, 3872, 3853, 3912, 3924, 3892, 3909, 3923, 3926,
#             ...
#             3931, 3842, 3841, 3879, 3939, 3883, 3911, 3881, 3847, 3848],
#            dtype='int64', length=107)
# user_id($29): 長度($108)
# ---------------
# Int64Index([3971, 3973, 3975, 4010, 4019, 3959, 3989, 3964, 3968, 3949,
#             ...
#             4030, 3953, 3956, 3983, 3998, 4037, 3987, 4047, 4049, 3946],
#            dtype='int64', length=108)
# user_id($30): 長度($43)
# ---------------
# Int64Index([4068, 4075, 4080, 4094, 4095, 4058, 4093, 4067, 4070, 4065, 4078,
#             4083, 4084, 4062, 4087, 4090, 4076, 4077, 4079, 4081, 4066, 4082,
#             4054, 4053, 4059, 4069, 4091, 4064, 4073, 4074, 4085, 4086, 4055,
#             4089, 4092, 4057, 4063, 4072, 4056, 4061, 4088, 4060, 4071],
#            dtype='int64')
# user_id($31): 長度($119)
# ---------------
# Int64Index([4174, 4177, 4181, 4204, 4164, 4193, 4197, 4192, 4099, 4205,
#             ...
#             4156, 4162, 4166, 4212, 4122, 4196, 4120, 4119, 4147, 4172],
#            dtype='int64', length=119)
# user_id($32): 長度($48)
# ---------------
# Int64Index([4227, 4258, 4240, 4230, 4234, 4252, 4251, 4216, 4245, 4215, 4241,
#             4261, 4257, 4232, 4233, 4255, 4259, 4253, 4237, 4236, 4256, 4249,
#             4262, 4231, 4219, 4247, 4260, 4235, 4244, 4223, 4224, 4226, 4229,
#             4239, 4243, 4246, 4250, 4228, 4248, 4218, 4222, 4254, 4242, 4225,
#             4220, 4238, 4221, 4217],
#            dtype='int64')
# user_id($33): 長度($391)
# ---------------
# Int64Index([4382, 4536, 4568, 4377, 4401, 4571, 4318, 4603, 4324, 4360,
#             ...
#             4595, 4336, 4386, 4379, 4312, 4635, 4380, 4274, 4334, 4402],
#            dtype='int64', length=391)
# user_id($34): 長度($164)
# ---------------
# Int64Index([4731, 4768, 4791, 4766, 4747, 4813, 4687, 4787, 4749, 4685,
#             ...
#             4807, 4680, 4741, 4748, 4799, 4803, 4788, 4723, 4658, 4795],
#            dtype='int64', length=164)
# user_id($35): 長度($198)
# ---------------
# Int64Index([5006, 4830, 4873, 4925, 4832, 4845, 4875, 4861, 4900, 4918,
#             ...
#             4833, 4856, 4909, 4982, 4992, 4907, 4965, 4892, 4948, 5003],
#            dtype='int64', length=198)
# user_id($36): 長度($351)
# ---------------
# Int64Index([5130, 5163, 5313, 5088, 5250, 5351, 5032, 5050, 5215, 5044,
#             ...
#             5364, 5262, 5069, 5280, 5222, 5104, 5062, 5076, 5126, 5180],
#            dtype='int64', length=351)
# user_id($37): 長度($53)
# ---------------
# Int64Index([5377, 5383, 5372, 5405, 5407, 5396, 5399, 5401, 5400, 5368, 5410,
#             5367, 5369, 5406, 5387, 5393, 5394, 5402, 5382, 5404, 5412, 5419,
#             5385, 5371, 5415, 5380, 5375, 5376, 5409, 5418, 5408, 5389, 5390,
#             5416, 5413, 5398, 5414, 5379, 5391, 5395, 5397, 5417, 5403, 5374,
#             5386, 5378, 5381, 5392, 5370, 5373, 5384, 5388, 5411],
#            dtype='int64')
# user_id($38): 長度($100)
# ---------------
# Int64Index([5428, 5479, 5467, 5516, 5498, 5454, 5473, 5513, 5456, 5470, 5431,
#             5442, 5449, 5458, 5486, 5469, 5461, 5500, 5505, 5515, 5425, 5472,
#             5484, 5504, 5477, 5488, 5423, 5434, 5511, 5455, 5457, 5450, 5497,
#             5495, 5478, 5430, 5493, 5499, 5441, 5475, 5437, 5466, 5440, 5448,
#             5482, 5444, 5462, 5465, 5483, 5496, 5502, 5512, 5421, 5506, 5508,
#             5445, 5460, 5510, 5451, 5463, 5471, 5514, 5501, 5518, 5492, 5436,
#             5446, 5438, 5439, 5503, 5491, 5494, 5453, 5519, 5422, 5474, 5435,
#             5420, 5459, 5507, 5489, 5509, 5517, 5480, 5485, 5447, 5432, 5468,
#             5429, 5476, 5487, 5424, 5426, 5427, 5443, 5452, 5490, 5464, 5433,
#             5481],
#            dtype='int64')
# user_id($39): 長度($62)
# ---------------
# Int64Index([5574, 5577, 5555, 5528, 5535, 5579, 5562, 5566, 5524, 5532, 5542,
#             5556, 5560, 5543, 5522, 5529, 5527, 5548, 5552, 5559, 5526, 5564,
#             5570, 5544, 5553, 5537, 5539, 5578, 5530, 5573, 5531, 5534, 5554,
#             5568, 5538, 5547, 5536, 5563, 5567, 5571, 5575, 5520, 5525, 5533,
#             5541, 5572, 5545, 5561, 5546, 5551, 5549, 5557, 5580, 5581, 5523,
#             5558, 5569, 5540, 5550, 5565, 5521, 5576],
#            dtype='int64')
# user_id($40): 長度($96)
# ---------------
# Int64Index([5628, 5661, 5643, 5655, 5656, 5588, 5595, 5625, 5648, 5651, 5584,
#             5590, 5592, 5646, 5606, 5614, 5641, 5582, 5591, 5607, 5650, 5660,
#             5664, 5640, 5596, 5627, 5630, 5665, 5675, 5662, 5622, 5634, 5645,
#             5676, 5624, 5638, 5672, 5642, 5589, 5611, 5613, 5583, 5659, 5670,
#             5671, 5601, 5623, 5644, 5657, 5668, 5585, 5598, 5615, 5586, 5593,
#             5605, 5673, 5609, 5603, 5612, 5620, 5667, 5602, 5604, 5621, 5669,
#             5616, 5653, 5600, 5677, 5587, 5649, 5608, 5652, 5658, 5663, 5666,
#             5610, 5626, 5632, 5633, 5639, 5637, 5647, 5597, 5599, 5635, 5674,
#             5594, 5629, 5636, 5617, 5631, 5654, 5618, 5619],
#            dtype='int64')
# user_id($41): 長度($25)
# ---------------
# Int64Index([5695, 5692, 5682, 5700, 5694, 5681, 5699, 5678, 5687, 5698, 5684,
#             5679, 5701, 5686, 5691, 5697, 5680, 5690, 5683, 5689, 5702, 5693,
#             5685, 5688, 5696],
#            dtype='int64')
# user_id($42): 長度($231)
# ---------------
# Int64Index([5727, 5830, 5888, 5818, 5707, 5763, 5852, 5721, 5747, 5761,
#             ...
#             5740, 5773, 5820, 5724, 5794, 5746, 5847, 5865, 5925, 5874],
#            dtype='int64', length=231)
# user_id($43): 長度($24)
# ---------------
# Int64Index([5949, 5948, 5952, 5957, 5940, 5944, 5936, 5937, 5939, 5935, 5938,
#             5951, 5943, 5954, 5941, 5942, 5955, 5946, 5956, 5953, 5945, 5947,
#             5934, 5950],
#            dtype='int64')
# user_id($44): 長度($193)
# ---------------
# Int64Index([6140, 6062, 6099, 6090, 6026, 6098, 5964, 5961, 6083, 6100,
#             ...
#             6032, 6036, 6022, 6113, 6020, 6010, 6045, 5972, 6091, 6081],
#            dtype='int64', length=193)
# user_id($45): 長度($297)
# ---------------
# Int64Index([6169, 6301, 6243, 6262, 6367, 6389, 6404, 6429, 6281, 6282,
#             ...
#             6395, 6421, 6201, 6398, 6248, 6411, 6333, 6358, 6441, 6311],
#            dtype='int64', length=297)
# user_id($46): 長度($41)
# ---------------
# Int64Index([6479, 6455, 6477, 6450, 6458, 6456, 6460, 6463, 6464, 6465, 6466,
#             6473, 6476, 6478, 6480, 6482, 6487, 6467, 6468, 6469, 6470, 6471,
#             6472, 6474, 6475, 6453, 6484, 6488, 6461, 6485, 6451, 6454, 6449,
#             6452, 6457, 6459, 6462, 6481, 6483, 6486, 6448],
#            dtype='int64')
# user_id($47): 長度($22)
# ---------------
# Int64Index([6489, 6501, 6503, 6494, 6509, 6504, 6490, 6491, 6498, 6500, 6508,
#             6505, 6493, 6497, 6510, 6506, 6502, 6507, 6492, 6495, 6496, 6499],
# Int64Index([9928, 9964, 9981, 9923, 9982, 9947, 9925, 9929, 9934, 9927, 9968,
#             9970, 9922, 9950, 9984, 9958, 9983, 9959, 9960, 9935, 9944, 9971,
#             9943, 9973, 9980, 9930, 9969, 9937, 9957, 9963, 9965, 9961, 9932,
#             9967, 9975, 9966, 9921, 9931, 9941, 9976, 9945, 9938, 9962, 9955,
#             9952, 9953, 9956, 9979, 9940, 9946, 9939, 9951, 9926, 9936, 9942,
#             9949, 9985, 9933, 9948, 9954, 9977, 9924, 9972, 9974, 9978],
#            dtype='int64')
# user_id($70): 長度($54)
# ---------------
# Int64Index([10018, 10020,  9990, 10004, 10038, 10012, 10017, 10022, 10031,
#             10033,  9996, 10024, 10032,  9989, 10027, 10039,  9998, 10028,
#             10008, 10014, 10034, 10036,  9994, 10002, 10003, 10019, 10023,
#             10037, 10000, 10015, 10016, 10025, 10029,  9988,  9993,  9999,
#             10010, 10021, 10013, 10035, 10005,  9992, 10006, 10009, 10030,
#              9995, 10007, 10011, 10026,  9997, 10001,  9986,  9991,  9987],
#            dtype='int64')
# user_id($71): 長度($29)
# ---------------
# Int64Index([10045, 10046, 10051, 10057, 10044, 10041, 10061, 10063, 10068,
#             10047, 10066, 10054, 10040, 10062, 10064, 10060, 10058, 10042,
#             10050, 10053, 10055, 10059, 10043, 10052, 10067, 10048, 10049,
#             10056, 10065],
#            dtype='int64')
# user_id($72): 長度($43)
# ---------------
# Int64Index([10106, 10088, 10080, 10111, 10079, 10077, 10108, 10107, 10084,
#             10070, 10087, 10078, 10086, 10093, 10104, 10101, 10085, 10091,
#             10071, 10073, 10074, 10098, 10082, 10099, 10090, 10097, 10076,
#             10089, 10083, 10102, 10095, 10069, 10103, 10092, 10109, 10075,
#             10105, 10072, 10100, 10110, 10096, 10081, 10094],
#            dtype='int64')
# user_id($73): 長度($255)
# ---------------
# Int64Index([10134, 10188, 10121, 10294, 10327, 10315, 10347, 10329, 10344,
#             10119,
#             ...
#             10253, 10325, 10213, 10232, 10359, 10149, 10313, 10177, 10142,
#             10323],
#            dtype='int64', length=255)
# user_id($74): 長度($43)
# ---------------
# Int64Index([10381, 10388, 10393, 10386, 10396, 10367, 10369, 10372, 10375,
#             10378, 10373, 10387, 10403, 10409, 10391, 10394, 10395, 10399,
#             10406, 10368, 10400, 10397, 10379, 10398, 10383, 10389, 10407,
#             10382, 10384, 10380, 10390, 10377, 10371, 10376, 10401, 10408,
#             10404, 10370, 10402, 10405, 10374, 10385, 10392],
#            dtype='int64')
# user_id($75): 長度($175)
# ---------------
# Int64Index([10581, 10460, 10500, 10565, 10428, 10529, 10552, 10426, 10434,
#             10458,
#             ...
#             10579, 10438, 10503, 10501, 10534, 10541, 10512, 10495, 10497,
#             10538],
#            dtype='int64', length=175)
# user_id($76): 長度($87)
# ---------------
# Int64Index([10599, 10608, 10618, 10640, 10642, 10662, 10588, 10594, 10668,
#             10607, 10651, 10664, 10589, 10655, 10629, 10647, 10592, 10603,
#             10638, 10649, 10597, 10625, 10659, 10666, 10631, 10639, 10641,
#             994967, 994971, 994972, 994984, 994988, 994960, 994986, 994970,
#             994980, 994982, 994992],
#            dtype='int64')
# user_id($6009): 長度($64)
# ---------------
# Int64Index([995017, 995047, 995022, 995008, 994997, 995000, 995007, 995035,
#             995036, 995006, 995015, 995021, 995012, 995053, 994996, 995020,
#             995056, 995009, 995013, 995014, 995057, 995046, 995055, 995048,
#             995039, 995011, 995003, 995001, 995032, 995050, 995044, 995023,
#             995028, 995045, 995049, 995041, 995051, 995027, 995037, 995043,
#             995002, 995005, 995040, 995052, 995004, 995058, 995033, 995018,
#             995034, 995042, 995019, 994995, 995024, 995031, 995026, 995016,
#             995029, 995054, 995010, 995025, 995030, 994999, 995038, 994998],
#            dtype='int64')
# user_id($6010): 長度($317)
# ---------------
# Int64Index([995100, 995156, 995325, 995235, 995255, 995347, 995112, 995194,
#             995309, 995261,
#             ...
#             995106, 995110, 995286, 995290, 995135, 995089, 995272, 995316,
#             995107, 995172],
#            dtype='int64', length=317)
# user_id($6011): 長度($197)
# ---------------
# Int64Index([995400, 995411, 995471, 995482, 995496, 995528, 995406, 995409,
#             995422, 995444,
#             ...
#             995475, 995412, 995427, 995454, 995452, 995522, 995507, 995558,
#             995508, 995519],
#            dtype='int64', length=197)
# user_id($6012): 長度($23)
# ---------------
# Int64Index([995574, 995581, 995585, 995587, 995591, 995594, 995573, 995579,
#             995580, 995583, 995588, 995575, 995584, 995590, 995595, 995577,
#             995586, 995589, 995593, 995576, 995578, 995592, 995582],
#            dtype='int64')
# user_id($6013): 長度($124)
# ---------------
# Int64Index([995698, 995703, 995623, 995632, 995664, 995686, 995615, 995685,
#             995656, 995661,
#             ...
#             995704, 995711, 995606, 995597, 995699, 995702, 995719, 995712,
#             995674, 995715],
#            dtype='int64', length=124)
# user_id($6014): 長度($106)
# ---------------
# Int64Index([995751, 995753, 995805, 995823, 995745, 995763, 995792, 995802,
#             995814, 995738,
#             ...
#             995796, 995815, 995818, 995765, 995740, 995773, 995795, 995806,
#             995812, 995809],
#            dtype='int64', length=106)
# user_id($6015): 長度($57)
# ---------------
# Int64Index([995835, 995839, 995841, 995857, 995861, 995845, 995849, 995878,
#             995826, 995827, 995830, 995843, 995865, 995877, 995829, 995831,
#             995832, 995833, 995847, 995870, 995881, 995848, 995863, 995879,
#             995840, 995836, 995838, 995852, 995855, 995866, 995854, 995873,
#             995858, 995880, 995837, 995846, 995850, 995844, 995862, 995864,
#             995828, 995856, 995868, 995851, 995867, 995869, 995874, 995876,
#             995834, 995842, 995853, 995882, 995872, 995875, 995859, 995871,
#             995860],
#            dtype='int64')
# user_id($6016): 長度($909)
# ---------------
# Int64Index([996779, 996789, 996201, 996295, 996331, 995895, 996284, 996482,
#             996709, 996485,
#             ...
#             996746, 996637, 996337, 996520, 996777, 996710, 996521, 996603,
#             996774, 996524],
#            dtype='int64', length=909)
# user_id($6017): 長度($33)
# ---------------
# Int64Index([996818, 996796, 996807, 996809, 996813, 996819, 996822, 996823,
#             996797, 996802, 996814, 996792, 996806, 996824, 996793, 996795,
# Int64Index([998120, 998149, 998165, 998131, 998135, 998148, 998154, 998158,
#             998163, 998168, 998130, 998162, 998150, 998153, 998157, 998164,
#             998166, 998143, 998159, 998133, 998136, 998128, 998160, 998152,
#             998121, 998134, 998144, 998137, 998161, 998125, 998124, 998127,
#             998126, 998147, 998119, 998145, 998156, 998138, 998169, 998141,
#             998146, 998122, 998140, 998167, 998132, 998151, 998123, 998142,
#             998155, 998129, 998139],
#            dtype='int64')
# user_id($6032): 長度($104)
# ---------------
# Int64Index([998172, 998198, 998273, 998199, 998267, 998211, 998213, 998209,
#             998210, 998192,
#             ...
#             998245, 998266, 998203, 998265, 998171, 998178, 998237, 998264,
#             998173, 998174],
#            dtype='int64', length=104)
# user_id($6033): 長度($60)
# ---------------
# Int64Index([998296, 998313, 998327, 998332, 998284, 998281, 998316, 998278,
#             998311, 998315, 998276, 998289, 998294, 998331, 998314, 998307,
#             998326, 998328, 998280, 998286, 998304, 998305, 998323, 998333,
#             998285, 998293, 998325, 998298, 998320, 998329, 998301, 998303,
#             998322, 998292, 998300, 998302, 998306, 998319, 998330, 998277,
#             998283, 998288, 998299, 998308, 998317, 998274, 998275, 998279,
#             998318, 998295, 998309, 998310, 998324, 998291, 998297, 998321,
#             998282, 998287, 998290, 998312],
#            dtype='int64')
# user_id($6034): 長度($21)
# ---------------
# Int64Index([998336, 998340, 998342, 998350, 998353, 998334, 998337, 998341,
#             998344, 998345, 998349, 998352, 998354, 998339, 998346, 998347,
#             998348, 998351, 998335, 998338, 998343],
#            dtype='int64')
# user_id($6035): 長度($280)
# ---------------
# Int64Index([998369, 998467, 998577, 998609, 998423, 998405, 998524, 998359,
#             998439, 998444,
#             ...
#             998390, 998512, 998459, 998535, 998537, 998575, 998427, 998570,
#             998587, 998435],
#            dtype='int64', length=280)
# user_id($6036): 長度($888)
# ---------------
# Int64Index([999375, 998735, 998784, 998822, 999372, 998787, 998818, 998819,
#             998845, 998996,
#             ...
#             999480, 998690, 998760, 999075, 999262, 999358, 998803, 998805,
#             999076, 999251],
#            dtype='int64', length=888)
# user_id($6037): 長度($202)
# ---------------
# Int64Index([999568, 999602, 999646, 999658, 999719, 999591, 999696, 999723,
#             999537, 999611,
#             ...
#             999598, 999678, 999546, 999681, 999700, 999596, 999682, 999713,
#             999557, 999684],
#            dtype='int64', length=202)
# user_id($6038): 長度($20)
# ---------------
# Int64Index([999726, 999743, 999735, 999732, 999734, 999740, 999744, 999730,
#             999733, 999737, 999742, 999727, 999728, 999729, 999736, 999738,
#             999739, 999725, 999741, 999731],
#            dtype='int64')
# user_id($6039): 長度($123)
# ---------------
# Int64Index([999794, 999850, 999746, 999775, 999822, 999748, 999783, 999785,
#             999803, 999836,
#             ...
#             999823, 999772, 999825, 999861, 999847, 999798, 999764, 999771,
#             999815, 999826],
#            dtype='int64', length=123)
# user_id($6040): 長度($341)
# ---------------
# Int64Index([1000138,  999873, 1000153, 1000007, 1000192,  999868,  999877,
#              999920,  999967,  999980,
#             ...
#             1000169, 1000105, 1000118, 1000119,  999923, 1000019,  999988,
#             1000172, 1000167, 1000042],
#            dtype='int64', length=341)

# %%
# 抓出單一個group

list(groups[1])
# Out:
# [31,
#  22,
#  27,
#  37,
#  24,
#  36,
#  3,
#  7,
#  47,
#  0,
#  21,
#  44,
#  9,
#  51,
#  43,
#  41,
#  48,
#  18,
#  11,
#  14,
#  42,
#  17,
#  39,
#  45,
#  26,
#  2,
#  6,
#  19,
#  38,
#  52,
#  1,
#  13,
#  49,
#  50,
#  15,
#  20,
#  46,
#  5,
#  8,
#  12,
#  28,
#  23,
#  10,
#  16,
#  29,
#  33,
#  40,
#  4,
#  30,
#  35,
#  32,
#  34,
#  25]

# %%
lengths
# Out:
# 1000209

# %%
# 平均看影片長度

lengths // len(groups)
# Out:
# 165

# %%
# 大概會有幾筆資料

mean_length = 120
L = 50
num_users = len(users)

(mean_length - L) * num_users * 0.15
# Out:
# 63420.0

# %%
# 輸入長度L: 50
# 不足長度怎麼處理?
# 1. 補0
# 2. 不使用
# 爆了, 檔案太大!


L = 50

def get_raw_input(groups):
    global L
    rows, temp = [], []
    for key in groups:
        if len(groups[key]) < L:
            continue
            # temp = list(groups) + [0]*(L-len(groups[key]))
        else:
            temp = list(groups)
        for i in range(0, len(temp)-L):
            # 將資料包裝
            rows.append(temp[i:i+L])
            
    return rows


rows = get_raw_input(groups)

# %%
for i in range(3):
    pprint(rows[i])

# %% [markdown]
# ## 模型架構
# - Encoder part
# - Classifier part

# %%
# config, 透過dataclass decorator自動加入__init__

from dataclasses import dataclass


@dataclass
class BERT4RecConfig:
    max_len: int=128
    batch_size: int=128
    lr: float=0.001
    item_size: int=num_movies
    embed_dim: int=16
    num_heads: int=8
    ff_dim: int=16
    num_layers: int=2
    dropout_rate: float=0.2
    
    
config = BERT4RecConfig()
config
# Out:
# BERT4RecConfig(max_len=128, batch_size=128, lr=0.001, item_size=3953, embed_dim=16, num_heads=8, ff_dim=16, num_layers=2, dropout_rate=0.2)

# %% [markdown]
# ![Trm -
# Encoder](trm_encoder.png)
#
# ---
#
# ![image.png](bert4rec.png)

# %%
def trm_encoder(q, k, v, i):
    """
        Encoder part
    """
    attention_output = layers.MultiHeadAttention(
        num_heads=config.num_heads,
        key_dim=config.embed_dim // config.num_heads,
        name=f'encoder_{i}/multiheadattention'
    )(q, k, v)
    attention_output = layers.Dropout(rate=config.dropout_rate, name=f'encoder_{i}/att_dropout')(attention_output)
    attention_output = layers.LayerNormalization(
        epsilon=1e-1, name=f'encoder_{i}/att_layernormalization'
    )(q + attention_output)                 # short-cut

    # ffn
    ffn = keras.Sequential([
        layers.Dense(config.ff_dim, activation='relu'),
        layers.Dense(config.embed_dim),          
    ], name=f"encoder_{i}/ffn")
    ffn_output = ffn(attention_output)
    ffn_output = layers.Dropout(0.1, name=f"encoder_{i}/ffn_dropout")(
        ffn_output
    )
    sequence_output = layers.LayerNormalization(
        epsilon=1e-6, name=f"encoder_{i}/ffn_layernormalization"
    )(attention_output + ffn_output)            # short-cut
    return sequence_output

# %%
# 透過繼承於 keras.Model 去細緻調整fit過程
loss_fn = keras.losses.SparseCategoricalCrossentropy(
    reduction=tf.keras.losses.Reduction.NONE
)
loss_tracker = tf.keras.metrics.Mean(name="loss")


class BERT4RecMLM(keras.Model):
    def train_step(self, inputs):
        if len(inputs) == 2:
            features, labels = inputs
            sample_weight = None
        elif len(inputs) == 3:
            features, labels, sample_weight = inputs
        else:
            print('輸入有誤...(BERT4RecMLM)')
        
        with tf.GradientTape() as tape:
            predictions = self(features, training=True)
            loss = loss_fn(labels, predictions, sample_weight=sample_weight)
        
        # 計算梯度
        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        
        # 參數更新
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))
        
        # 計算 metrics
        loss_tracker.update_state(loss, sample_weight=sample_weight)
        
        return {'loss': loss_tracker.result()}
    
    @property
    def metrics(self):
        return [loss_tracker]

# %%
def create_bert4rec():
    # input
    inputs = keras.Input(shape=(config.max_len,), dtype='int64', name='input')
    # Embedding(item + pos)
    item_embedding_layer = layers.Embedding(
        input_dim=config.item_size,
        output_dim=config.embed_dim,
        name='item_embedding'
    )
    item_embedding = item_embedding_layer(inputs)
    pos_embedding = layers.Embedding(
        input_dim=config.max_len,
        output_dim=config.embed_dim,
        name='pos_embedding'
    )(tf.range(start=0, limit=config.max_len, delta=1))
    embedding = item_embedding + pos_embedding
    
    # Encoder
    for i in range(config.num_layers):
        embedding = trm_encoder(embedding, embedding, embedding, i)
    
    # output layer, share embedding(這邊不是layer應該不能直接操作...不符合functional API) ---> 發現可以!!!
    outputs = tf.matmul(embedding, tf.transpose(a=item_embedding_layer.trainable_variables[0]))
    outputs = layers.Activation('softmax')(outputs)
    
    model = BERT4RecMLM(inputs, outputs)
    model.compile(optimizer=keras.optimizers.Adam(config.lr))
    return model

    
bert4rec = create_bert4rec()
bert4rec.summary()
# Out:
# Model: "ber_t4rec_mlm_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 128)]        0
# __________________________________________________________________________________________________
# item_embedding (Embedding)      (None, 128, 16)      63248       input[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_26 (TFOpLa (None, 128, 16)      0           item_embedding[0][0]
# __________________________________________________________________________________________________
# encoder_0/multiheadattention (M (None, 128, 16)      1088        tf.__operators__.add_26[0][0]
#                                                                  tf.__operators__.add_26[0][0]
#                                                                  tf.__operators__.add_26[0][0]
# __________________________________________________________________________________________________
# encoder_0/att_dropout (Dropout) (None, 128, 16)      0           encoder_0/multiheadattention[0][0
# __________________________________________________________________________________________________
# tf.__operators__.add_27 (TFOpLa (None, 128, 16)      0           tf.__operators__.add_26[0][0]
#                                                                  encoder_0/att_dropout[0][0]
# __________________________________________________________________________________________________
# encoder_0/att_layernormalizatio (None, 128, 16)      32          tf.__operators__.add_27[0][0]
# __________________________________________________________________________________________________
# encoder_0/ffn (Sequential)      (None, 128, 16)      544         encoder_0/att_layernormalization[
# __________________________________________________________________________________________________
# encoder_0/ffn_dropout (Dropout) (None, 128, 16)      0           encoder_0/ffn[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_28 (TFOpLa (None, 128, 16)      0           encoder_0/att_layernormalization[
#                                                                  encoder_0/ffn_dropout[0][0]
# __________________________________________________________________________________________________
# encoder_0/ffn_layernormalizatio (None, 128, 16)      32          tf.__operators__.add_28[0][0]
# __________________________________________________________________________________________________
# encoder_1/multiheadattention (M (None, 128, 16)      1088        encoder_0/ffn_layernormalization[
#                                                                  encoder_0/ffn_layernormalization[
#                                                                  encoder_0/ffn_layernormalization[
# __________________________________________________________________________________________________
# encoder_1/att_dropout (Dropout) (None, 128, 16)      0           encoder_1/multiheadattention[0][0
# __________________________________________________________________________________________________
# tf.__operators__.add_29 (TFOpLa (None, 128, 16)      0           encoder_0/ffn_layernormalization[
#                                                                  encoder_1/att_dropout[0][0]
# __________________________________________________________________________________________________
# encoder_1/att_layernormalizatio (None, 128, 16)      32          tf.__operators__.add_29[0][0]
# __________________________________________________________________________________________________
# encoder_1/ffn (Sequential)      (None, 128, 16)      544         encoder_1/att_layernormalization[
# __________________________________________________________________________________________________
# encoder_1/ffn_dropout (Dropout) (None, 128, 16)      0           encoder_1/ffn[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_30 (TFOpLa (None, 128, 16)      0           encoder_1/att_layernormalization[
#                                                                  encoder_1/ffn_dropout[0][0]
# __________________________________________________________________________________________________
# encoder_1/ffn_layernormalizatio (None, 128, 16)      32          tf.__operators__.add_30[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_5 (TFOpLambda) (None, 128, 3953)    0           encoder_1/ffn_layernormalization[
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 3953)    0           tf.linalg.matmul_5[0][0]
# ==================================================================================================
# Total params: 66,640
# Trainable params: 66,640
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## embedding 輸入輸出共享測試

# %%
# 找出 共享 embedding 方法, 需要轉置
emd = layers.Embedding(10000, 32)
embedding = emd(np.array([1,2, 3]))

emd.weights
# Out:
# [<tf.Variable 'embedding_9/embeddings:0' shape=(10000, 32) dtype=float32, numpy=
#  array([[-0.04565385,  0.0228415 ,  0.01408012, ...,  0.02277399,
#           0.03881348, -0.02892498],
#         [ 0.00531975,  0.01409591,  0.04157652, ..., -0.02709459,
#          -0.04011021, -0.02030834],
#         [ 0.04395641,  0.03908107,  0.03616558, ..., -0.04538272,
#          -0.02270526, -0.04050515],
#         ...,
#         [ 0.03277861,  0.04361615,  0.03682769, ..., -0.0142963 ,
#          -0.00953268,  0.00386209],
#         [-0.04249771,  0.02699311, -0.03973543, ..., -0.04423676,
#           0.01094314,  0.03270457],
#         [ 0.00862191,  0.01632955,  0.03811376, ...,  0.04757805,
#           0.00394714,  0.04658416]], dtype=float32)>]

# %%
# 轉置! 但這需要該layer 要記住名稱

tf.transpose(a=emd.trainable_variables[0])
# Out:
# <tf.Tensor: shape=(32, 10000), dtype=float32, numpy=
# array([[-0.04565385,  0.00531975,  0.04395641, ...,  0.03277861,
#         -0.04249771,  0.00862191],
#        [ 0.0228415 ,  0.01409591,  0.03908107, ...,  0.04361615,
#          0.02699311,  0.01632955],
#        [ 0.01408012,  0.04157652,  0.03616558, ...,  0.03682769,
#         -0.03973543,  0.03811376],
#        ...,
#        [ 0.02277399, -0.02709459, -0.04538272, ..., -0.0142963 ,
#         -0.04423676,  0.04757805],
#        [ 0.03881348, -0.04011021, -0.02270526, ..., -0.00953268,
#          0.01094314,  0.00394714],
#        [-0.02892498, -0.02030834, -0.04050515, ...,  0.00386209,
#          0.03270457,  0.04658416]], dtype=float32)>

# %%
# 可以使用!, 但應該要在call裡面使用, 所以需要用繼承keras.Model模式來寫!

tf.matmul(embedding, tf.transpose(a=emd.trainable_variables[0]))
# Out:
# <tf.Tensor: shape=(3, 10000), dtype=float32, numpy=
# array([[ 0.00295702,  0.02385878,  0.00536622, ...,  0.00704855,
#          0.00206965,  0.00226169],
#        [-0.00061949,  0.00536622,  0.02979579, ..., -0.00245284,
#         -0.00624401,  0.00031275],
#        [ 0.00046163, -0.00302564, -0.0011524 , ..., -0.00433287,
#          0.00389158,  0.00151961]], dtype=float32)>

# %%
# model 輸入測試確保可以使用

inputs = np.array([[1000]*128], dtype=np.int64)
bert4rec(inputs)
# Out:
# <tf.Tensor: shape=(1, 128, 3953), dtype=float32, numpy=
# array([[[0.00020181, 0.00022673, 0.00022804, ..., 0.00030195,
#          0.00026357, 0.00021186],
#         [0.00021734, 0.00025212, 0.00020987, ..., 0.00028276,
#          0.00026578, 0.00024568],
#         [0.0002291 , 0.00020995, 0.00027308, ..., 0.00027523,
#          0.0002666 , 0.00022405],
#         ...,
#         [0.00022932, 0.00021925, 0.00025138, ..., 0.0002734 ,
#          0.00029029, 0.00022199],
#         [0.00022149, 0.0002334 , 0.00020401, ..., 0.00027082,
#          0.00031555, 0.00025754],
#         [0.00022589, 0.00023743, 0.00023314, ..., 0.00027141,
#          0.00026577, 0.00022947]]], dtype=float32)>

# %%
# 預測

np.argmax(tf.nn.softmax(bert4rec(inputs)), axis=2)
# Out:
# array([[3573, 3768, 3682,   73, 3719, 2715, 3573,  122,  377, 3573, 3573,
#         3573, 3299, 3573, 2356, 3573, 3573, 3573, 2204, 1109,   73, 1304,
#         3573, 1109,  449, 3573, 2343, 1304, 3118, 1073, 3573, 2343, 3573,
#           73, 1861,  903, 1007,  733, 3385, 3573, 1109,  810, 3573, 1109,
#         2343, 1290, 3901, 1304, 1109, 3385, 3573,  377, 3573, 1304, 1382,
#         3719, 2285,   73, 3573, 3573, 1085, 3441, 1011, 1992,  794, 2715,
#         2385,  794, 3573,  733,  733,   73, 1534, 3573, 3026, 2382, 3131,
#         1109,  794, 2715, 3573, 2715, 3118, 2193, 3573, 2718,  377, 3078,
#         3118,  377, 3573, 1304, 3056,  903, 2715, 1109, 1304, 1109, 3385,
#         3573,   73, 2343, 1109, 3573, 1853, 3719, 3719, 3594, 2343, 3901,
#         1109, 2715, 3573, 2382, 2382, 3573,   73,  429, 3573,   73, 3901,
#         2969, 1304, 3573, 1109, 1109, 3476,  903]], dtype=int64)

# %% [markdown]
# ## **接著需要**
#
# - 將[mask] token 放入 vocabulary(可以採用與text 同樣方式, 透過TextVectorization方式 or not)
# - 將輸入資料mask: portion = 0.4
# - 測試訓練
# - 負樣本
# - 正式訓練

# %%
# [mask] token ---> ok

# 將輸入資料mask: 先將資料轉換成seq data, 但要直接用numpy 還是 用成 檔案閱讀 成dataset呢?
# 以擴充來說, dataset更好, 但目前以實現為原則, 先用numpy ---> 記憶體爆開
# 那採取 寫成txt檔案, user_id,裡面每一row為 [movied_id1, movie_id2,  ... movied_id_length]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-57bba148b66e> in <module>
#       5 # 那採取 寫成txt檔案, user_id,裡面每一row為 [movied_id1, movie_id2,  ... movied_id_length]
#       6
# ----> 7 config
#
# NameError: name 'config' is not defined
